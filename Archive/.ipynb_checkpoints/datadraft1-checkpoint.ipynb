# %%
# Import dependencies
import requests
import json
from pprint import pprint

# %%
# URL to get request
url = "https://developers.zomato.com/api/v2.1/search?entity_id=281&entity_type=city&start=1&count=100"
headers = {'user-key': "56f8a64be7b09ee8c81a59edfd692b34", "accept": "application/json"}

# %%
# Jupyter Only, test connection
# Print the response object to the console
print(requests.get(url, headers=headers))
# Out:
# <Response [200]>

# %%
# Pretty print
response = requests.get(url, headers=headers).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "restaurants": [
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16819715
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 20,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Sandwich",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16819715",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/philippe-the-original-chinatown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16819715_RESTAURANT_d8c5a8adc5406e3a159186b82b1b3d56_c.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16819715",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "1001 N Alameda Street, Los Angeles 90012",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0597210000",
#                     "locality": "North Alameda Street, Chinatown",
#                     "locality_verbose": "North Alameda Street, Chinatown, Los Angeles",
#                     "longitude": "-118.2370250000",
#                     "zipcode": "90012"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/philippe-the-original-chinatown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Philippe, The Original",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/philippe-the-original-chinatown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16819715_RESTAURANT_d8c5a8adc5406e3a159186b82b1b3d56_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/philippe-the-original-chinatown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.9",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "677"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16831684
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 40,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Italian",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16831684",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/bottega-louie-downtown/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16831684_RESTAURANT_b36e38b5d5021de7be403c7e713777a1_c.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16831684",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "700 S Grand Ave, Los Angeles 90017",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0469319000",
#                     "locality": "South Grand Avenue, Downtown",
#                     "locality_verbose": "South Grand Avenue, Downtown, Los Angeles",
#                     "longitude": "-118.2566807000",
#                     "zipcode": "90017"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/bottega-louie-downtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Bottega Louie",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/bottega-louie-downtown/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 3,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16831684_RESTAURANT_b36e38b5d5021de7be403c7e713777a1_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/bottega-louie-downtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.9",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "752"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16820124
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 40,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Italian, Pizza",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16820124",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/pizzeria-mozza-melrose/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16820124",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "641 North Highland Avenue 90036",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0822700000",
#                     "locality": "North Highland Avenue, Melrose",
#                     "locality_verbose": "North Highland Avenue, Melrose, Los Angeles",
#                     "longitude": "-118.3385800000",
#                     "zipcode": "90036"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/pizzeria-mozza-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Pizzeria Mozza",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/pizzeria-mozza-melrose/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 3,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/pizzeria-mozza-melrose?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.8",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "597"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16813268
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Breakfast, Coffee and Tea",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16813268",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/the-griddle-cafe-hollywood/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16813268_RESTAURANT_a89c88ce962903fe4962c3c4f1728b04.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16813268",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "7916 W Sunset Blvd, West Hollywood 90046",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0977993000",
#                     "locality": "Sunset Boulevard, Hollywood",
#                     "locality_verbose": "Sunset Boulevard, Hollywood, Los Angeles",
#                     "longitude": "-118.3622528000",
#                     "zipcode": "90046"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/the-griddle-cafe-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "The Griddle Cafe",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/the-griddle-cafe-hollywood/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16813268_RESTAURANT_a89c88ce962903fe4962c3c4f1728b04.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/the-griddle-cafe-hollywood?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.8",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "497"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16810917
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 10,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Desserts",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16810917",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/diddy-riese-cookies-westwood/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16810917",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "926 Broxton Avenue 90024",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0633500000",
#                     "locality": "Westwood",
#                     "locality_verbose": "Westwood",
#                     "longitude": "-118.4469500000",
#                     "zipcode": "90024"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/diddy-riese-cookies-westwood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Diddy Riese Cookies",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/diddy-riese-cookies-westwood/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 1,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/diddy-riese-cookies-westwood?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.9",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "476"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16830386
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 10,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "German",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16830386",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/wurstk\u00fcche-wholesale-district/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16830386_RESTAURANT_4838a856aac0beef4e5bf7481716c83c_c.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16830386",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "800 East 3rd Street 90013",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0456400000",
#                     "locality": "East 3rd Street, Wholesale District",
#                     "locality_verbose": "East 3rd Street, Wholesale District, Los Angeles",
#                     "longitude": "-118.2352800000",
#                     "zipcode": "90013"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/wurstk\u00fcche-wholesale-district/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Wurstk\u00fcche",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/wurstk\u00fcche-wholesale-district/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 1,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16830386_RESTAURANT_4838a856aac0beef4e5bf7481716c83c_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/wurstk\u00fcche-wholesale-district?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.9",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "539"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16825829
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16825829",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/gjelina-venice/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16825829_RESTAURANT_51f7344eab23eec68db763890f20386e_c.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16825829",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "1429 Abbot Kinney Blvd, Venice 90291",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "33.9905070000",
#                     "locality": "Venice",
#                     "locality_verbose": "Venice",
#                     "longitude": "-118.4649280000",
#                     "zipcode": "90291"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/gjelina-venice/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Gjelina",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/gjelina-venice/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16825829_RESTAURANT_51f7344eab23eec68db763890f20386e_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/gjelina-venice?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.7",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "470"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16821118
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 10,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Southern",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16821118",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/roscoes-house-of-chicken-waffles-hollywood/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16821118_RESTAURANT_8161f8e23d3856025c618525ab32b467.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16821118",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "1514 N Gower St, Hollywood 92802",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0986575000",
#                     "locality": "Hollywood",
#                     "locality_verbose": "Hollywood",
#                     "longitude": "-118.3221660000",
#                     "zipcode": "92802"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/roscoes-house-of-chicken-waffles-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Roscoe's House of Chicken & Waffles",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/roscoes-house-of-chicken-waffles-hollywood/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 1,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16821118_RESTAURANT_8161f8e23d3856025c618525ab32b467.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/roscoes-house-of-chicken-waffles-hollywood?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.8",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "501"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16830337
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 70,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Spanish, Tapas",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16830337",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/the-bazaar-by-jose-andres-1-carthay/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16830337",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "465 La Cienega Boulevard, Beverly Hills 90048",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0796000000",
#                     "locality": "La Cienega Boulevard, Carthay",
#                     "locality_verbose": "La Cienega Boulevard, Carthay, Los Angeles",
#                     "longitude": "-118.3766400000",
#                     "zipcode": "90048"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/the-bazaar-by-jose-andres-1-carthay/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "The Bazaar by Jose Andres",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/the-bazaar-by-jose-andres-1-carthay/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 4,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/the-bazaar-by-jose-andres-1-carthay?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.5",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "346"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16825758
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 40,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16825758",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/animal-melrose/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16825758",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "435 N Fairfax Ave, Los Angeles 90036",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0792171000",
#                     "locality": "North Fairfax Avenue, Melrose",
#                     "locality_verbose": "North Fairfax Avenue, Melrose, Los Angeles",
#                     "longitude": "-118.3616044000",
#                     "zipcode": "90036"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/animal-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Animal",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/animal-melrose/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 3,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/animal-melrose?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.6",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "301"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16808460
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Brazilian, Latin American, Pizza",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16808460",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/bossa-nova-brazilian-cuisine-hollywood/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16808460",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "7181 W Sunset Blvd, Los Angeles 90046",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0982102000",
#                     "locality": "Sunset Boulevard, Hollywood",
#                     "locality_verbose": "Sunset Boulevard, Hollywood, Los Angeles",
#                     "longitude": "-118.3466258000",
#                     "zipcode": "90046"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/bossa-nova-brazilian-cuisine-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Bossa Nova Brazilian Cuisine",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/bossa-nova-brazilian-cuisine-hollywood/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/bossa-nova-brazilian-cuisine-hollywood?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.7",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "368"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16825525
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 70,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Italian",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16825525",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/osteria-mozza-melrose/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16825525",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "6602 Melrose Avenue, Hollywood 90038",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0831900000",
#                     "locality": "North Highland Avenue, Melrose",
#                     "locality_verbose": "North Highland Avenue, Melrose, Los Angeles",
#                     "longitude": "-118.3395100000",
#                     "zipcode": "90038"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/osteria-mozza-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Osteria Mozza",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/osteria-mozza-melrose/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 4,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/osteria-mozza-melrose?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.6",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "378"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16814344
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 70,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, California",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16814344",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/the-ivy-carthay/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16814344_RESTAURANT_af2eecb850c9662c8d133ac62ca9de0b.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16814344",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "113 North Robertson Boulevard 90048",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0765100000",
#                     "locality": "Carthay",
#                     "locality_verbose": "Carthay",
#                     "longitude": "-118.3838000000",
#                     "zipcode": "90048"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/the-ivy-carthay/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "The Ivy",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/the-ivy-carthay/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 4,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16814344_RESTAURANT_af2eecb850c9662c8d133ac62ca9de0b.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/the-ivy-carthay?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.3",
#                     "rating_color": "5BA829",
#                     "rating_text": "Very Good",
#                     "votes": "221"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16809318
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Deli",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16809318",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/canters-melrose/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16809318",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "419 North Fairfax Avenue 90036",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0785900000",
#                     "locality": "North Fairfax Avenue, Melrose",
#                     "locality_verbose": "North Fairfax Avenue, Melrose, Los Angeles",
#                     "longitude": "-118.3615300000",
#                     "zipcode": "90036"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/canters-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Canters",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/canters-melrose/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/canters-melrose?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.3",
#                     "rating_color": "5BA829",
#                     "rating_text": "Very Good",
#                     "votes": "258"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16825707
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Burger",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16825707",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/fathers-office-regent-square/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "https://b.zmtcdn.com/data/res_imagery/16825707_RESTAURANT_824350d3acd5b1edf7fd8758526c613a_c.jpg",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16825707",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "3229 Helms Ave, Los Angeles 90034",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0304053000",
#                     "locality": "Helms Ave, Regent Square",
#                     "locality_verbose": "Helms Ave, Regent Square, Los Angeles",
#                     "longitude": "-118.3848103000",
#                     "zipcode": "90034"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/fathers-office-regent-square/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Father's Office",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/fathers-office-regent-square/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "https://b.zmtcdn.com/data/res_imagery/16825707_RESTAURANT_824350d3acd5b1edf7fd8758526c613a_c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A",
#                 "url": "https://www.zomato.com/los-angeles/fathers-office-regent-square?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.5",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "365"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16820386
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 70,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "French, Seafood",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16820386",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/providence-melrose/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16820386",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "5955 Melrose Ave, Los Angeles 90038",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0836552000",
#                     "locality": "Melrose Avenue, Melrose",
#                     "locality_verbose": "Melrose Avenue, Melrose, Los Angeles",
#                     "longitude": "-118.3302427000",
#                     "zipcode": "90038"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/providence-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Providence",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/providence-melrose/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 4,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/providence-melrose?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.4",
#                     "rating_color": "5BA829",
#                     "rating_text": "Very Good",
#                     "votes": "213"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16814205
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 15,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Burger, Fast Food",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16814205",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/in-n-out-burger-hollywood/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16814205",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "7009 Sunset Boulevard, , Los Angeles 90028",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0981919000",
#                     "locality": "Sunset Boulevard, Hollywood",
#                     "locality_verbose": "Sunset Boulevard, Hollywood, Los Angeles",
#                     "longitude": "-118.3416924000",
#                     "zipcode": "90028"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/in-n-out-burger-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "In-N-Out Burger",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/in-n-out-burger-hollywood/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 1,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/in-n-out-burger-hollywood?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.7",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "282"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16807074
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 25,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "American, Coffee and Tea",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16807074",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/alcove-cafe-bakery-los-feliz/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16807074",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "1929 Hillhurst Ave, Los Angeles 90027",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.1063127000",
#                     "locality": "Hillhurst Avenue, Los Feliz",
#                     "locality_verbose": "Hillhurst Avenue, Los Feliz, Los Angeles",
#                     "longitude": "-118.2877515000",
#                     "zipcode": "90027"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/alcove-cafe-bakery-los-feliz/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Alcove Cafe & Bakery",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/alcove-cafe-bakery-los-feliz/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/alcove-cafe-bakery-los-feliz?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.7",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "293"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16807372
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 20,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Burger, Desserts",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16807372",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/the-apple-pan-rancho-park/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16807372",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "10801 W Pico Boulevard, Los Angeles 90064",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0407174000",
#                     "locality": "West Pico Boulevard, Rancho Park",
#                     "locality_verbose": "West Pico Boulevard, Rancho Park, Los Angeles",
#                     "longitude": "-118.4277921000",
#                     "zipcode": "90064"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/the-apple-pan-rancho-park/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "The Apple Pan",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/the-apple-pan-rancho-park/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 2,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/the-apple-pan-rancho-park?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.6",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "362"
#                 }
#             }
#         },
#         {
#             "restaurant": {
#                 "R": {
#                     "res_id": 16810579
#                 },
#                 "apikey": "56f8a64be7b09ee8c81a59edfd692b34",
#                 "average_cost_for_two": 10,
#                 "book_again_url": "",
#                 "book_form_web_view_url": "",
#                 "cuisines": "Japanese",
#                 "currency": "$",
#                 "deeplink": "zomato://restaurant/16810579",
#                 "establishment_types": [],
#                 "events_url": "https://www.zomato.com/los-angeles/daikokuya-little-tokyo/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "featured_image": "",
#                 "has_online_delivery": 0,
#                 "has_table_booking": 0,
#                 "id": "16810579",
#                 "include_bogo_offers": true,
#                 "is_book_form_web_view": 0,
#                 "is_delivering_now": 0,
#                 "is_table_reservation_supported": 0,
#                 "is_zomato_book_res": 0,
#                 "location": {
#                     "address": "327 E 1st St, Los Angeles 90012",
#                     "city": "Los Angeles",
#                     "city_id": 281,
#                     "country_id": 216,
#                     "latitude": "34.0500021000",
#                     "locality": "Little Tokyo",
#                     "locality_verbose": "Little Tokyo",
#                     "longitude": "-118.2400679000",
#                     "zipcode": "90012"
#                 },
#                 "menu_url": "https://www.zomato.com/los-angeles/daikokuya-little-tokyo/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop",
#                 "mezzo_provider": "OTHER",
#                 "name": "Daikokuya",
#                 "offers": [],
#                 "opentable_support": 0,
#                 "photos_url": "https://www.zomato.com/los-angeles/daikokuya-little-tokyo/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop",
#                 "price_range": 1,
#                 "switch_to_order_menu": 0,
#                 "thumb": "",
#                 "url": "https://www.zomato.com/los-angeles/daikokuya-little-tokyo?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1",
#                 "user_rating": {
#                     "aggregate_rating": "4.8",
#                     "rating_color": "3F7E00",
#                     "rating_text": "Excellent",
#                     "votes": "331"
#                 }
#             }
#         }
#     ],
#     "results_found": 22578,
#     "results_shown": 20,
#     "results_start": 1
# }

# %%
with open('restaurant.json', 'w') as json_file:  
    json.dump(response, json_file)

# %%
import pymysql, os, json
file = os.path.abspath('restaurant.json')
json_data= open(file).read()
json_obj = json.loads(json_data)

# %%
# connect to MySQL
con = pymysql.connect(host = 'localhost',user = 'root',passwd = 'root',db = 'test')
cursor = con.cursor()


# parse json data to SQL insert
for i, item in enumerate(json_obj):
    person = validate_string(item.get("person", None))
    year = validate_string(item.get("year", None))
    company = validate_string(item.get("company", None))

    cursor.execute("INSERT INTO testp (person,	year,	company) VALUES (%s,	%s,	%s)", (person,	year,	company))
con.commit()
con.close()

# %%
name = response["re staurants"][0]["restaurant"]["name"]
ave_cost = response["restaurants"][0]["restaurant"]["average_cost_for_two"]
cuisines = response["restaurants"][0]["restaurant"]["cuisines"]
price_range = response["restaurants"][0]["restaurant"]["price_range"]
featured_image = response["restaurants"][0]["restaurant"]["featured_image"]
menu = response["restaurants"][0]["restaurant"]["menu_url"]
lat = response["restaurants"][0]["restaurant"]["location"]["latitude"]
long= response["restaurants"][0]["restaurant"]["location"]["longitude"]
rating = response["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"]
vote = response["restaurants"][0]["restaurant"]["user_rating"]["votes"]

# %%
# The "response" property in articles contains the actual articles# list comprehension.
restaurant_names = response["restaurants"][0]["restaurant"]["name"]
only_restaurants = response["restaurants"]
restaurant_list = [name["restaurant"]["name"] for name in only_restaurants]
pprint(restaurant_list)

# %%
# Sample code to interate through json and store into a list
restaurant_response = response["restaurants"]
restaurant_names = []

for res in restaurant_response:
    restaurant_names.append(res["restaurant"]["name"])

# %% [markdown]
# Create SQL

# %%
# Import SQL Alchemy
from sqlalchemy import create_engine

# Import PyMySQL (Not needed if mysqlclient is installed)
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
# Create restaurant class
# ----------------------------------
class RestaurantData(Base):
    __tablename__ = 'restaurants'
    id = Column(Integer, primary_key=True)
    name = Column(String(255))
    lat = Column(Float(5))
    lng = Column(Float(5))
    cuisine = Column(String(255))
    ave_cost = Column(Float(2))
    rating = Column(Integer)
    vote = Column(Integer)
    price_range = Column(Integer)
    featured_image = Column(String(255))
    menu = Column(String(255))

# %%
# Create instances that will be used to add to the table object

# %%
# Create Database Connection
# ----------------------------------
# Establish Connection to MySQL
# engine = create_engine('mysql://root:mypassword@data-bootcamp-rutgers.cn6jzamkgcqr.us-west-2.rds.amazonaws.com:3306/surfingdb')
engine = create_engine("sqlite:///surfer.sqlite")
conn = engine.connect()

# %%
# Create both the Surfer and Board tables within the database
Base.metadata.create_all(conn)

# %%
# To push the objects made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add instances to the current session need to create the instances_variable from the j_son
session.add(instances_variable)

# Commit both objects to the database
session.commit()

# %% [markdown]
# Columns
# name = response["restaurants"][0]["restaurant"]["name"]
# lat = response["restaurants"][0]["restaurant"]["location"]["latitude"]
# long= response["restaurants"][0]["restaurant"]["location"]["longitude"]
# cuisines = response["restaurants"][0]["restaurant"]["cuisines"]
# ave_cost = response["restaurants"][0]["restaurant"]["average_cost_for_two"]
# rating = response["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"]
# vote = response["restaurants"][0]["restaurant"]["user_rating"]["votes"]
# currency = response["restaurants"][0]["restaurant"]["currency"]
# featured_image = response["restaurants"][0]["restaurant"]["featured_image"]
# menu = response["restaurants"][0]["restaurant"]["menu_url"]
#
# class RestaurantData(Base):
#     __tablename__ = 'restaurants'
#     id = Column(Integer, primary_key=True)
#     name = Column(String(255))
#     lat = Column(Float(5))
#     lng = Column(Float(5))
#     cuisine = Column(String(255))
#     ave_cost = Column(Float(2))
#     rating = Column(Integer)
#     vote = Column(Integer)
#     currency = Column(Integer)
#     featured_image = Column(String(255))
#     menu = Column(String(255))

# %%
# Query the database and collect all of the surfers in the Surfer table
instance_list = session.query(RestaurantData)
for instance in instance_list:
    print(instance.name)
    print(instance.lat)
    print(instance.lng)
    print(instance.ave_cost)
    print(instance.rating)
    print(instance.vote)
    print(instance.price_range)
    print(instance.featured_image)
    print(instance.menu)
