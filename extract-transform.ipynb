# %%
# Import dependencies
import requests
import json
from pprint import pprint

# %%
# URL to get request
url = "https://developers.zomato.com/api/v2.1/search?entity_id=281&entity_type=city&start=1&count=100"
headers = {'user-key': "56f8a64be7b09ee8c81a59edfd692b34", "accept": "application/json"}

# %%
# Jupyter Only, test connection
# Print the response object to the console
print(requests.get(url, headers=headers))
# Out:
# <Response [200]>

# %%
# Pretty print
response = requests.get(url, headers=headers).json()

# %%
with open('restaurant.json', 'w') as json_file:  
    json.dump(response, json_file)

# %%
with open('restaurant.json', 'r') as JSON:
       dict = json.load(JSON)

# %%
restaurants = dict["restaurants"]

# %%
# loop through the json file and extract the data we need create a dictionary object
#for i in dict:
cleaned_dict = []

def transform(r):
    return {
    "name": r["restaurant"]["name"],
    "ave_cost": r["restaurant"]["average_cost_for_two"],
    "cuisines": r["restaurant"]["cuisines"],
    "price_range": r["restaurant"]["price_range"],
    "featured_image": r["restaurant"]["featured_image"],
    "menu": r["restaurant"]["menu_url"],
    "lat": r["restaurant"]["location"]["latitude"],
    "lng": r["restaurant"]["location"]["longitude"],
    "rating": r["restaurant"]["user_rating"]["aggregate_rating"],
    "vote": r["restaurant"]["user_rating"]["votes"]
    }

for r in restaurants:
    transformed_dict = transform(r)
    cleaned_dict.append(transformed_dict)

# %%
cleaned_dict
# Out:
# [{'name': 'Philippe, The Original',
#   'ave_cost': 20,
#   'cuisines': 'American, Sandwich',
#   'price_range': 2,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16819715_RESTAURANT_d8c5a8adc5406e3a159186b82b1b3d56_c.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/philippe-the-original-chinatown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0597210000',
#   'lng': '-118.2370250000',
#   'rating': '4.9',
#   'vote': '677'},
#  {'name': 'Bottega Louie',
#   'ave_cost': 40,
#   'cuisines': 'Italian',
#   'price_range': 3,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16831684_RESTAURANT_b36e38b5d5021de7be403c7e713777a1_c.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/bottega-louie-downtown/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0469319000',
#   'lng': '-118.2566807000',
#   'rating': '4.9',
#   'vote': '752'},
#  {'name': 'Pizzeria Mozza',
#   'ave_cost': 40,
#   'cuisines': 'Italian, Pizza',
#   'price_range': 3,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/pizzeria-mozza-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0822700000',
#   'lng': '-118.3385800000',
#   'rating': '4.8',
#   'vote': '597'},
#  {'name': 'The Griddle Cafe',
#   'ave_cost': 25,
#   'cuisines': 'American, Breakfast, Coffee and Tea',
#   'price_range': 2,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16813268_RESTAURANT_a89c88ce962903fe4962c3c4f1728b04.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/the-griddle-cafe-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0977993000',
#   'lng': '-118.3622528000',
#   'rating': '4.8',
#   'vote': '497'},
#  {'name': 'Diddy Riese Cookies',
#   'ave_cost': 10,
#   'cuisines': 'Desserts',
#   'price_range': 1,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/diddy-riese-cookies-westwood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0633500000',
#   'lng': '-118.4469500000',
#   'rating': '4.9',
#   'vote': '476'},
#  {'name': 'Wurstküche',
#   'ave_cost': 10,
#   'cuisines': 'German',
#   'price_range': 1,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16830386_RESTAURANT_4838a856aac0beef4e5bf7481716c83c_c.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/wurstküche-wholesale-district/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0456400000',
#   'lng': '-118.2352800000',
#   'rating': '4.9',
#   'vote': '539'},
#  {'name': 'Gjelina',
#   'ave_cost': 25,
#   'cuisines': 'American',
#   'price_range': 2,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16825829_RESTAURANT_51f7344eab23eec68db763890f20386e_c.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/gjelina-venice/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '33.9905070000',
#   'lng': '-118.4649280000',
#   'rating': '4.7',
#   'vote': '470'},
#  {'name': "Roscoe's House of Chicken & Waffles",
#   'ave_cost': 10,
#   'cuisines': 'Southern',
#   'price_range': 1,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16821118_RESTAURANT_8161f8e23d3856025c618525ab32b467.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/roscoes-house-of-chicken-waffles-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0986575000',
#   'lng': '-118.3221660000',
#   'rating': '4.8',
#   'vote': '501'},
#  {'name': 'The Bazaar by Jose Andres',
#   'ave_cost': 70,
#   'cuisines': 'Spanish, Tapas',
#   'price_range': 4,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/the-bazaar-by-jose-andres-1-carthay/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0796000000',
#   'lng': '-118.3766400000',
#   'rating': '4.5',
#   'vote': '346'},
#  {'name': 'Animal',
#   'ave_cost': 40,
#   'cuisines': 'American',
#   'price_range': 3,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/animal-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0792171000',
#   'lng': '-118.3616044000',
#   'rating': '4.6',
#   'vote': '301'},
#  {'name': 'Bossa Nova Brazilian Cuisine',
#   'ave_cost': 25,
#   'cuisines': 'Brazilian, Latin American, Pizza',
#   'price_range': 2,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/bossa-nova-brazilian-cuisine-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0982102000',
#   'lng': '-118.3466258000',
#   'rating': '4.7',
#   'vote': '368'},
#  {'name': 'Osteria Mozza',
#   'ave_cost': 70,
#   'cuisines': 'Italian',
#   'price_range': 4,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/osteria-mozza-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0831900000',
#   'lng': '-118.3395100000',
#   'rating': '4.6',
#   'vote': '378'},
#  {'name': 'The Ivy',
#   'ave_cost': 70,
#   'cuisines': 'American, California',
#   'price_range': 4,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16814344_RESTAURANT_af2eecb850c9662c8d133ac62ca9de0b.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/the-ivy-carthay/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0765100000',
#   'lng': '-118.3838000000',
#   'rating': '4.3',
#   'vote': '221'},
#  {'name': 'Canters',
#   'ave_cost': 25,
#   'cuisines': 'American, Deli',
#   'price_range': 2,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/canters-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0785900000',
#   'lng': '-118.3615300000',
#   'rating': '4.3',
#   'vote': '258'},
#  {'name': "Father's Office",
#   'ave_cost': 25,
#   'cuisines': 'American, Burger',
#   'price_range': 2,
#   'featured_image': 'https://b.zmtcdn.com/data/res_imagery/16825707_RESTAURANT_824350d3acd5b1edf7fd8758526c613a_c.jpg',
#   'menu': 'https://www.zomato.com/los-angeles/fathers-office-regent-square/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0304053000',
#   'lng': '-118.3848103000',
#   'rating': '4.5',
#   'vote': '365'},
#  {'name': 'Providence',
#   'ave_cost': 70,
#   'cuisines': 'French, Seafood',
#   'price_range': 4,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/providence-melrose/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0836552000',
#   'lng': '-118.3302427000',
#   'rating': '4.4',
#   'vote': '213'},
#  {'name': 'In-N-Out Burger',
#   'ave_cost': 15,
#   'cuisines': 'American, Burger, Fast Food',
#   'price_range': 1,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/in-n-out-burger-hollywood/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0981919000',
#   'lng': '-118.3416924000',
#   'rating': '4.7',
#   'vote': '282'},
#  {'name': 'Alcove Cafe & Bakery',
#   'ave_cost': 25,
#   'cuisines': 'American, Coffee and Tea',
#   'price_range': 2,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/alcove-cafe-bakery-los-feliz/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.1063127000',
#   'lng': '-118.2877515000',
#   'rating': '4.7',
#   'vote': '293'},
#  {'name': 'The Apple Pan',
#   'ave_cost': 20,
#   'cuisines': 'Burger, Desserts',
#   'price_range': 2,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/the-apple-pan-rancho-park/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0407174000',
#   'lng': '-118.4277921000',
#   'rating': '4.6',
#   'vote': '362'},
#  {'name': 'Daikokuya',
#   'ave_cost': 10,
#   'cuisines': 'Japanese',
#   'price_range': 1,
#   'featured_image': '',
#   'menu': 'https://www.zomato.com/los-angeles/daikokuya-little-tokyo/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#   'lat': '34.0500021000',
#   'lng': '-118.2400679000',
#   'rating': '4.8',
#   'vote': '331'}]
